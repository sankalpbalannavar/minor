# %%
import os
import numpy as np
from nibabel.testing import data_path
import matplotlib.pyplot as plt

# %%
data = os.path.join(data_path, "C:\\Users\\HPC\\Desktop\\ImageCHD_dataset\\ct_1054_image.nii.gz")

# %%
import nibabel as nib
img = nib.load(data)

# %%
img.shape
# Out:
# (512, 512, 168)

# %%
slice=img.get_fdata()
slice.shape
# Out:
# (512, 512, 168)

# %%
plt.imshow(slice[:,:,100])
